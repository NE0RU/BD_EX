# %%
from selenium import webdriver as wb
from bs4 import BeautifulSoup as bs
import time
import pandas as pd

# %%
from selenium import webdriver as wb
from selenium.webdriver.common.keys import Keys

# %%
url = 'http://www.momstouch.co.kr/main/main.php'

driver = wb.Chrome()
driver.get(url)

# %%
btn_search = driver.find_element_by_class_name('li_02')
btn_search.click()
# Out:
# ---------------------------------------------------------------------------
# ElementClickInterceptedException          Traceback (most recent call last)
# <ipython-input-4-36ec89bd66fc> in <module>
#       1 btn_search = driver.find_element_by_class_name('li_02')
# ----> 2 btn_search.click()
#
# C:\Users\NEORU\anaconda3\envs\deep\lib\site-packages\selenium\webdriver\remote\webelement.py in click(self)
#      78     def click(self):
#      79         """Clicks the element."""
# ---> 80         self._execute(Command.CLICK_ELEMENT)
#      81
#      82     def submit(self):
#
# C:\Users\NEORU\anaconda3\envs\deep\lib\site-packages\selenium\webdriver\remote\webelement.py in _execute(self, command, params)
#     631             params = {}
#     632         params['id'] = self._id
# --> 633         return self._parent.execute(command, params)
#     634
#     635     def find_element(self, by=By.ID, value=None):
#
# ...

# %%
input_search = driver.find_element_by_class_name('search_input')
input_search.send_keys('광주')
input_search.send_keys(Keys.ENTER)

# %%
soup = bs(driver.page_source,'html.parser')
soup
# Out:
# <html><head>
# <title>맘스터치</title>
# <meta content="text/html; charset=utf-8" http-equiv="CONTENT-TYPE"/>
# <meta content="IE=Edge" http-equiv="X-UA-Compatible"/>
# <meta content=" '빠르게보다 ALL바르게' 엄마의 정성을 담은 수제버거&amp;치킨 브랜드 맘스터치 입니다." name="description"/>
# <meta content="맘스터치, momstouch, 맘스터치 메뉴, 맘스터치 위치, 맘스터치 창업, 싸이버거, 화이트갈릭버거" name="keywords"/>
# <meta content="5427c12a6d26d3b80ec447505ad0ca6bd191a5b0" name="naver-site-verification"/>
# <script async="" src="https://www.google-analytics.com/analytics.js"></script><script async="" src="https://connect.facebook.net/signals/config/884390701904777?v=2.9.24&amp;r=stable"></script><script async="" src="https://connect.facebook.net/en_US/fbevents.js"></script><script src="../../lib/lib.js.php" type="text/javascript"></script>
# <script type="text/javascript">
# <!--
# function render_view(seq) {
#   location.href = "./store_01_view.html?pg=1&seq="+seq+"&area=&ss=광주";
# }
#
# function schecked(frm){
# 	if (frm.ss.value == ''){
# ...

# %%
name_list = []
addr_list = []
tel_list = []

names = soup.select('#mCSB_3_container > .quickSearchResultBoxSidoGugun > li > strong')
addrs = soup.select('#mCSB_3_container > .quickSearchResultBoxSidoGugun > li > strong + p')
print(len(names), len(addrs))
# Out:
# 0 0

# %%
soup.select("span.store_list_td")
# Out:
# []

# %%
for index in range(len(names)):
    names = soup.select("#contents > div > table > tbody > tr > td")[index]
    index = index+5
names
# Out:
# <td>경기</td>

# %%
soup1.find_all("td")
# Out:
# [<td>경기</td>,
#  <td><a href="javascript:render_view('1551');">경기광주양벌점</a></td>,
#  <td class="td_Left"><a href="javascript:render_view('1551');">경기도 광주시 오포읍 양벌로 299, 1층 108, 109호</a></td>,
#  <td>031-763-0229</td>,
#  <td><a href="javascript:render_view('1551');"><img alt="view" src="../../img/common/btn/btn_view.gif"/></a></td>,
#  <td>광주</td>,
#  <td><a href="javascript:render_view('1547');">광주첨단2지구점</a></td>,
#  <td class="td_Left"><a href="javascript:render_view('1547');">광주광역시 북구 첨단연신로 97, 솔로몬빌딩 102호</a></td>,
#  <td>062-571-1777</td>,
#  <td><a href="javascript:render_view('1547');"><img alt="view" src="../../img/common/btn/btn_view.gif"/></a></td>,
#  <td>광주</td>,
#  <td><a href="javascript:render_view('1507');">일곡점</a></td>,
#  <td class="td_Left"><a href="javascript:render_view('1507');">광주광역시 북구 설죽로 503 1층 </a></td>,
#  <td>062-576-5045</td>,
#  <td><a href="javascript:render_view('1507');"><img alt="view" src="../../img/common/btn/btn_view.gif"/></a></td>,
# ...

# %%
soup1 = soup.find("table", {"class": "store_List"})

# %%
soup1.find_all("td", {"class": "td_Left"})
# Out:
# [<td class="td_Left"><a href="javascript:render_view('1551');">경기도 광주시 오포읍 양벌로 299, 1층 108, 109호</a></td>,
#  <td class="td_Left"><a href="javascript:render_view('1547');">광주광역시 북구 첨단연신로 97, 솔로몬빌딩 102호</a></td>,
#  <td class="td_Left"><a href="javascript:render_view('1507');">광주광역시 북구 설죽로 503 1층 </a></td>,
#  <td class="td_Left"><a href="javascript:render_view('1471');">광주광역시 북구 서하로 187</a></td>,
#  <td class="td_Left"><a href="javascript:render_view('1338');">광주광역시 북구 양산택지로 57,1층</a></td>,
#  <td class="td_Left"><a href="javascript:render_view('1302');">광주 서구 치평로 79(치평동) 상무프라자</a></td>,
#  <td class="td_Left"><a href="javascript:render_view('1285');">경기 광주시 곤지암읍 곤지암로 36 1층</a></td>,
#  <td class="td_Left"><a href="javascript:render_view('1257');">경기도 광주시 오포읍 신현로 84, 1동 1층</a></td>,
#  <td class="td_Left"><a href="javascript:render_view('1148');">경기 광주시 고불로 46번길 4</a></td>,
#  <td class="td_Left"><a href="javascript:render_view('1139');">경기 광주시 경안로 17</a></td>]

# %%
soup1.find_all("a")
# Out:
# [<a href="javascript:render_view('1551');">경기광주양벌점</a>,
#  <a href="javascript:render_view('1551');">경기도 광주시 오포읍 양벌로 299, 1층 108, 109호</a>,
#  <a href="javascript:render_view('1551');"><img alt="view" src="../../img/common/btn/btn_view.gif"/></a>,
#  <a href="javascript:render_view('1547');">광주첨단2지구점</a>,
#  <a href="javascript:render_view('1547');">광주광역시 북구 첨단연신로 97, 솔로몬빌딩 102호</a>,
#  <a href="javascript:render_view('1547');"><img alt="view" src="../../img/common/btn/btn_view.gif"/></a>,
#  <a href="javascript:render_view('1507');">일곡점</a>,
#  <a href="javascript:render_view('1507');">광주광역시 북구 설죽로 503 1층 </a>,
#  <a href="javascript:render_view('1507');"><img alt="view" src="../../img/common/btn/btn_view.gif"/></a>,
#  <a href="javascript:render_view('1471');">광주오치매곡점</a>,
#  <a href="javascript:render_view('1471');">광주광역시 북구 서하로 187</a>,
#  <a href="javascript:render_view('1471');"><img alt="view" src="../../img/common/btn/btn_view.gif"/></a>,
# ...

# %%
btn_next = driver.find_element_by_class_name('page_next')
btn_next.click()
